# %% [markdown]
# <span style="color:blue">
#
# # Visualization Test Data
#
# <span>

# %%
import pandas as pd

# %%
data_test = pd.read_csv("Titanic/test.csv")

# %% [markdown]
# <span style="color:blue">
#
# <br>
#
# We need to identify the `NaN` values, because we cannot simply delete the raw data as I initially thought.
#
# <br>
#
# <span>

# %%
data_test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# <span style="color:blue">
#
# <br>
#
# The `Cabin` column will be suppressed, that's not a problem. However, we need to replace the `NaN` values of the `Age` and `Fare` variable with some value, for example the median age of the passengers.
#
# <br>
#
# <span>
